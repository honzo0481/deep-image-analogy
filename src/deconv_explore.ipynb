# %%
import matplotlib.pyplot as plt

from keras.applications.vgg19 import VGG19, preprocess_input
from deconv import Deconv
from scipy.misc import imread

# %matplotlib inline

# %%
feature_layers = ['block1_conv1', 'block2_conv1', 'block3_conv1', 'block4_conv1', 'block5_conv1']

# %%
model = Deconv(VGG19, preprocess_input, '../images/2style2style/A1.png')

# %%
reconstructed_img = model.deconv(
    layer='block5_conv1',
    save_images=False,
    iterations=10)

# %%
from matplotlib.image import imread

f, axarr = plt.subplots(1,2, figsize=(16,50))
axarr[0].imshow(imread('../images/2style2style/A1.png'))
axarr[0].axis('off')
axarr[1].imshow(reconstructed_img)
axarr[1].axis('off')
# Out:
# (-0.5, 447.5, 447.5, -0.5)

# %%
fig = plt.figure(figsize=(50,50))
for i in range(10):
    a = fig.add_subplot(1, 10, i+1)
    fname = result_prefix + '2_at_iteration_%d.png' % i
    image = imread(fname)
    plt.imshow(image)
    plt.axis('off')
